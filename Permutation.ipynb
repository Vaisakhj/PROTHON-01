# %%
import itertools
[''.join(a) for a in itertools.permutations('Protosem')]
# Out:
# ['Protosem',
#  'Protosme',
#  'Protoesm',
#  'Protoems',
#  'Protomse',
#  'Protomes',
#  'Protsoem',
#  'Protsome',
#  'Protseom',
#  'Protsemo',
#  'Protsmoe',
#  'Protsmeo',
#  'Proteosm',
#  'Proteoms',
#  'Protesom',
#  'Protesmo',
#  'Protemos',
#  'Protemso',
#  'Protmose',
#  'Protmoes',
#  'Protmsoe',
#  'Protmseo',
#  'Protmeos',
#  'Protmeso',
#  'Prootsem',
#  'Prootsme',
#  'Prootesm',
#  'Prootems',
#  'Prootmse',
#  'Prootmes',
#  'Proostem',
#  'Proostme',
#  'Proosetm',
#  'Proosemt',
#  'Proosmte',
#  'Proosmet',
#  'Prooetsm',
#  'Prooetms',
#  'Prooestm',
#  'Prooesmt',
#  'Prooemts',
#  'Prooemst',
#  'Proomtse',
#  'Proomtes',
#  'Proomste',
#  'Proomset',
#  'Proomets',
#  'Proomest',
#  'Prostoem',
#  'Prostome',
#  'Prosteom',
#  'Prostemo',
#  'Prostmoe',
#  'Prostmeo',
#  'Prosotem',
#  'Prosotme',
#  'Prosoetm',
#  'Prosoemt',
#  'Prosomte',
#  'Prosomet',
#  'Prosetom',
#  'Prosetmo',
#  'Proseotm',
#  'Proseomt',
#  'Prosemto',
#  'Prosemot',
# ...
